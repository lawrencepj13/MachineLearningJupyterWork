# %%
import numpy as np
import pandas as pd
from pandas import read_csv

#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension
wins_data.head(5)#first 5 rows
wins_data.tail(5)#last 5 rows
# Out:
# (699, 11)
#      sample_code  c_thickness  uni_cell_size  uni_cell_shape  marg_adhesion  \
# 694       776715            3              1               1              1
# 695       841769            2              1               1              1
# 696       888820            5             10              10              3
# 697       897471            4              8               6              4
# 698       897471            4              8               8              5
#
#      epi_cell_size nuclei  bland_chromatin  normal_nucleoli  mitoses  \
# 694              3      2                1                1        1
# 695              2      1                1                1        1
# 696              7      3                8               10        2
# 697              3      4               10                6        1
# 698              4      5               10                4        1
#
#      tumor_class
# 694            2
# 695            2
# 696            4
# ...

# %%
import numpy as np
import pandas as pd
from pandas import read_csv

#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#check data for missing values
win_empty_data=wins_data[wins_data.isna().any(axis=1)]
print('\nThese are the missing data sets:\n', win_empty_data)
#index is empty so there are no missinf values - good stuff!
# Out:
# (699, 11)
#
# These are the missing data sets:
#  Empty DataFrame
# Columns: [sample_code, c_thickness, uni_cell_size, uni_cell_shape, marg_adhesion, epi_cell_size, nuclei, bland_chromatin, normal_nucleoli, mitoses, tumor_class]
# Index: []

# %%
import numpy as np
import pandas as pd
from pandas import read_csv

#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#check the data types
print(wins_data.dtypes)
# Out:
# (699, 11)
# sample_code         int64
# c_thickness         int64
# uni_cell_size       int64
# uni_cell_shape      int64
# marg_adhesion       int64
# epi_cell_size       int64
# nuclei             object
# bland_chromatin     int64
# normal_nucleoli     int64
# mitoses             int64
# tumor_class         int64
# dtype: object

# %%
import numpy as np
import pandas as pd
from pandas import read_csv

#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#check the data instances that are not numeric in the nuclei variable
print(wins_data[pd.to_numeric(wins_data['nuclei'], errors='coerce').isnull()])
# Out:
# (699, 11)
#      sample_code  c_thickness  uni_cell_size  uni_cell_shape  marg_adhesion  \
# 23       1057013            8              4               5              1
# 40       1096800            6              6               6              9
# 139      1183246            1              1               1              1
# 145      1184840            1              1               3              1
# 158      1193683            1              1               2              1
# 164      1197510            5              1               1              1
# 235      1241232            3              1               4              1
# 249       169356            3              1               1              1
# 275       432809            3              1               3              1
# 292       563649            8              8               8              1
# 294       606140            1              1               1              1
# ...

# %%
import numpy as np
import pandas as pd
from pandas import read_csv

#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#convert nuclei variable to numeric and force non numeric to NAN
wins_data['nuclei']=pd.to_numeric(wins_data['nuclei'], errors='coerce')

#another test
# wins_data.apply(pd.to_numeric, errors='coerce').info()#this gives the datatype after conversion
# wins_data=wins_data.apply(pd.to_numeric, errors='coerce')
#this shows the columns that have non null - nuclei is only one with null values (16)

#check missing values
win_empty_data = wins_data[wins_data.isna().any(axis=1)]
print('\nThese are the missing data sets:\n', win_empty_data)
# Out:
# (699, 11)
#
# These are the missing data sets:
#       sample_code  c_thickness  uni_cell_size  uni_cell_shape  marg_adhesion  \
# 23       1057013            8              4               5              1
# 40       1096800            6              6               6              9
# 139      1183246            1              1               1              1
# 145      1184840            1              1               3              1
# 158      1193683            1              1               2              1
# 164      1197510            5              1               1              1
# 235      1241232            3              1               4              1
# 249       169356            3              1               1              1
# 275       432809            3              1               3              1
# 292       563649            8              8               8              1
# 294       606140            1              1               1              1
# ...

# %%
import numpy as np
import pandas as pd
from pandas import read_csv

#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#convert nuclei variable to numeric and force non numeric to NAN
wins_data['nuclei']=pd.to_numeric(wins_data['nuclei'], errors='coerce')

#check missing values
win_empty_data = wins_data[wins_data.isna().any(axis=1)]
# print('\nThese are the missing data sets:\n', win_empty_data)

#check the basic stats of the data
wins_data.describe()
# Out:
# (699, 11)
#         sample_code  c_thickness  uni_cell_size  uni_cell_shape  \
# count  6.990000e+02   699.000000     699.000000      699.000000
# mean   1.071704e+06     4.417740       3.134478        3.207439
# std    6.170957e+05     2.815741       3.051459        2.971913
# min    6.163400e+04     1.000000       1.000000        1.000000
# 25%    8.706885e+05     2.000000       1.000000        1.000000
# 50%    1.171710e+06     4.000000       1.000000        1.000000
# 75%    1.238298e+06     6.000000       5.000000        5.000000
# max    1.345435e+07    10.000000      10.000000       10.000000
#
#        marg_adhesion  epi_cell_size      nuclei  bland_chromatin  \
# count     699.000000     699.000000  683.000000       699.000000
# mean        2.806867       3.216023    3.544656         3.437768
# std         2.855379       2.214300    3.643857         2.438364
# min         1.000000       1.000000    1.000000         1.000000
# ...

# %%
import numpy as np
from sklearn import preprocessing
from pandas import set_option
from matplotlib import pyplot
from pandas.plotting import scatter_matrix
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
import pandas as pd
from pandas import read_csv

#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#check missing values
win_empty_data = wins_data[wins_data.isna().any(axis=1)]
# print('\nThese are the missing data sets:\n', win_empty_data)

#check the basic stats of the data
wins_data.describe()

#sample code number is just an index
#not useful for learning so we will drop it
wins_data.drop('sample_code', axis=1, inplace=True)
print(wins_data.head(5))
# Out:
# (699, 11)
#    c_thickness  uni_cell_size  uni_cell_shape  marg_adhesion  epi_cell_size  \
# 0            5              1               1              1              2
# 1            5              4               4              5              7
# 2            3              1               1              1              2
# 3            6              8               8              1              3
# 4            4              1               1              3              2
#
#   nuclei  bland_chromatin  normal_nucleoli  mitoses  tumor_class
# 0      1                3                1        1            2
# 1     10                3                2        1            2
# 2      2                3                1        1            2
# 3      4                3                7        1            2
# 4      1                3                1        1            2

# %%
import numpy as np
import pandas as pd
from pandas import read_csv

#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#convert nuclei variable to numeric and force non numeric to NAN
wins_data['nuclei']=pd.to_numeric(wins_data['nuclei'], errors='coerce')

#check missing values
win_empty_data = wins_data[wins_data.isna().any(axis=1)]
# print('\nThese are the missing data sets:\n', win_empty_data)

#because ? cannot be converted to int, we convert all data to float
wins_data[wisconsin_headers] = wins_data[wisconsin_headers].applymap(float)

#sample code number is just an index
#not useful for learning so we will drop it
wins_data.drop('sample_code', axis=1, inplace=True)
print(wins_data.head(5))
print(wins_data.dtypes)
# Out:
# (699, 11)
#    c_thickness  uni_cell_size  uni_cell_shape  marg_adhesion  epi_cell_size  \
# 0          5.0            1.0             1.0            1.0            2.0
# 1          5.0            4.0             4.0            5.0            7.0
# 2          3.0            1.0             1.0            1.0            2.0
# 3          6.0            8.0             8.0            1.0            3.0
# 4          4.0            1.0             1.0            3.0            2.0
#
#    nuclei  bland_chromatin  normal_nucleoli  mitoses  tumor_class
# 0     1.0              3.0              1.0      1.0          2.0
# 1    10.0              3.0              2.0      1.0          2.0
# 2     2.0              3.0              1.0      1.0          2.0
# 3     4.0              3.0              7.0      1.0          2.0
# 4     1.0              3.0              1.0      1.0          2.0
# c_thickness        float64
# uni_cell_size      float64
# uni_cell_shape     float64
# ...

# %%
import numpy as np
import pandas as pd
from pandas import read_csv
from sklearn.impute import SimpleImputer


#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#convert nuclei variable to numeric and force non numeric to NAN
wins_data['nuclei']=pd.to_numeric(wins_data['nuclei'], errors='coerce')

#check missing values
win_empty_data = wins_data[wins_data.isna().any(axis=1)]
# print('\nThese are the missing data sets:\n', win_empty_data)

#because ? cannot be converted to int, we convert all data to float
wins_data[wisconsin_headers] = wins_data[wisconsin_headers].applymap(float)

#sample code number is just an index
#not useful for learning so we will drop it
wins_data.drop('sample_code', axis=1, inplace=True)

#declaring new headers
new_wisconsin_headers = ['c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#use simpleimputer to replace missing values
imputer = SimpleImputer(strategy='mean')
imputer.fit(wins_data)
new_data = imputer.transform(wins_data)
wins_data = pd.DataFrame(new_data, columns = new_wisconsin_headers)
print(wins_data)
#re check our data for missing values
win_empty_data = wins_data[wins_data.isna().any(axis=1)]
print('\nMissing Data Afer Replacement:\n', win_empty_data)
# Out:
# (699, 11)
#      c_thickness  uni_cell_size  uni_cell_shape  marg_adhesion  epi_cell_size  \
# 0            5.0            1.0             1.0            1.0            2.0
# 1            5.0            4.0             4.0            5.0            7.0
# 2            3.0            1.0             1.0            1.0            2.0
# 3            6.0            8.0             8.0            1.0            3.0
# 4            4.0            1.0             1.0            3.0            2.0
# ..           ...            ...             ...            ...            ...
# 694          3.0            1.0             1.0            1.0            3.0
# 695          2.0            1.0             1.0            1.0            2.0
# 696          5.0           10.0            10.0            3.0            7.0
# 697          4.0            8.0             6.0            4.0            3.0
# 698          4.0            8.0             8.0            5.0            4.0
#
# ...

# %%
import numpy as np
import pandas as pd
from pandas import read_csv
from sklearn.impute import SimpleImputer
from matplotlib import pyplot


#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#convert nuclei variable to numeric and force non numeric to NAN
wins_data['nuclei']=pd.to_numeric(wins_data['nuclei'], errors='coerce')

#check missing values
win_empty_data = wins_data[wins_data.isna().any(axis=1)]
# print('\nThese are the missing data sets:\n', win_empty_data)

#because ? cannot be converted to int, we convert all data to float
wins_data[wisconsin_headers] = wins_data[wisconsin_headers].applymap(float)

#sample code number is just an index
#not useful for learning so we will drop it
wins_data.drop('sample_code', axis=1, inplace=True)

#declaring new headers
new_wisconsin_headers = ['c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#use simpleimputer to replace missing values
imputer = SimpleImputer(strategy='mean')
imputer.fit(wins_data)
new_data = imputer.transform(wins_data)
wins_data = pd.DataFrame(new_data, columns = new_wisconsin_headers)

#plot the histogram
wins_data.hist()
pyplot.show()
# Out:
# (699, 11)

# %%
import numpy as np
import pandas as pd
from pandas import read_csv
from sklearn.impute import SimpleImputer
from matplotlib import pyplot


#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#convert nuclei variable to numeric and force non numeric to NAN
wins_data['nuclei']=pd.to_numeric(wins_data['nuclei'], errors='coerce')

#check missing values
win_empty_data = wins_data[wins_data.isna().any(axis=1)]
# print('\nThese are the missing data sets:\n', win_empty_data)

#because ? cannot be converted to int, we convert all data to float
wins_data[wisconsin_headers] = wins_data[wisconsin_headers].applymap(float)

#sample code number is just an index
#not useful for learning so we will drop it
wins_data.drop('sample_code', axis=1, inplace=True)

#declaring new headers
new_wisconsin_headers = ['c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#use simpleimputer to replace missing values
imputer = SimpleImputer(strategy='mean')
imputer.fit(wins_data)
new_data = imputer.transform(wins_data)
wins_data = pd.DataFrame(new_data, columns = new_wisconsin_headers)

#get the data correlation
wins_data_correlations=wins_data.corr()

#plot the correlation
corr_fig = pyplot.figure()
axises=corr_fig.add_subplot(111)
axcorr=axises.matshow(wins_data_correlations, vmin=-1, vmax=1)

corr_fig.colorbar(axcorr)
ticks=np.arange(0,10,1)

#assign ticks and labels
axises.set_xticks(ticks)
axises.set_yticks(ticks)
axises.set_xticklabels(new_wisconsin_headers)
axises.set_yticklabels(new_wisconsin_headers)
pyplot.show()#displays plot #mostly positive correlations - mitoses and c thickness negative?
# Out:
# (699, 11)

# %%
import numpy as np
import pandas as pd
from pandas import read_csv
from sklearn.impute import SimpleImputer
from matplotlib import pyplot
from sklearn.model_selection import train_test_split


#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#convert nuclei variable to numeric and force non numeric to NAN
wins_data['nuclei']=pd.to_numeric(wins_data['nuclei'], errors='coerce')

#check missing values
win_empty_data = wins_data[wins_data.isna().any(axis=1)]
# print('\nThese are the missing data sets:\n', win_empty_data)

#because ? cannot be converted to int, we convert all data to float
wins_data[wisconsin_headers] = wins_data[wisconsin_headers].applymap(float)

#sample code number is just an index
#not useful for learning so we will drop it
wins_data.drop('sample_code', axis=1, inplace=True)

#declaring new headers
new_wisconsin_headers = ['c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#use simpleimputer to replace missing values
imputer = SimpleImputer(strategy='mean')
imputer.fit(wins_data)
new_data = imputer.transform(wins_data)
wins_data = pd.DataFrame(new_data, columns = new_wisconsin_headers)

#seperate data into x train and y test groups - y variable is tumor_class, rest is x
y=wins_data.pop('tumor_class')
X=wins_data

print(y.shape)
print(X.shape)
print(y) #shows the new data frame for x (training set)/y target set
# Out:
# (699, 11)
# (699,)
# (699, 9)
# 0      2.0
# 1      2.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 694    2.0
# 695    2.0
# 696    4.0
# 697    4.0
# 698    4.0
# Name: tumor_class, Length: 699, dtype: float64

# %%
import numpy as np
import pandas as pd
from pandas import read_csv
from sklearn.impute import SimpleImputer
from matplotlib import pyplot
from sklearn.model_selection import train_test_split


#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#convert nuclei variable to numeric and force non numeric to NAN
wins_data['nuclei']=pd.to_numeric(wins_data['nuclei'], errors='coerce')

#check missing values
win_empty_data = wins_data[wins_data.isna().any(axis=1)]
# print('\nThese are the missing data sets:\n', win_empty_data)

#because ? cannot be converted to int, we convert all data to float
wins_data[wisconsin_headers] = wins_data[wisconsin_headers].applymap(float)

#sample code number is just an index
#not useful for learning so we will drop it
wins_data.drop('sample_code', axis=1, inplace=True)

#declaring new headers
new_wisconsin_headers = ['c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#use simpleimputer to replace missing values
imputer = SimpleImputer(strategy='mean')
imputer.fit(wins_data)
new_data = imputer.transform(wins_data)
wins_data = pd.DataFrame(new_data, columns = new_wisconsin_headers)

#seperate data into x train and y test groups - y variable is tumor_class, rest is x
y=wins_data.pop('tumor_class')
X=wins_data

#split the data into train/test - using 60:40
#import the module from sklearnmodelselection
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

#check the dimensons of train and test sets
print('\n The total of the training dataset', X_train.shape)
print('\n The total of test dataset', X_test.shape)
# Out:
# (699, 11)
#
#  The total of the training dataset (419, 9)
#
#  The total of test dataset (280, 9)

# %%
import numpy as np
import pandas as pd
from pandas import read_csv
from sklearn.impute import SimpleImputer
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier


#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#convert nuclei variable to numeric and force non numeric to NAN
wins_data['nuclei']=pd.to_numeric(wins_data['nuclei'], errors='coerce')

#check missing values
win_empty_data = wins_data[wins_data.isna().any(axis=1)]
# print('\nThese are the missing data sets:\n', win_empty_data)

#because ? cannot be converted to int, we convert all data to float
wins_data[wisconsin_headers] = wins_data[wisconsin_headers].applymap(float)

#sample code number is just an index
#not useful for learning so we will drop it
wins_data.drop('sample_code', axis=1, inplace=True)

#declaring new headers
new_wisconsin_headers = ['c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#use simpleimputer to replace missing values
imputer = SimpleImputer(strategy='mean')
imputer.fit(wins_data)
new_data = imputer.transform(wins_data)
wins_data = pd.DataFrame(new_data, columns = new_wisconsin_headers)

#seperate data into x train and y test groups - y variable is tumor_class, rest is x
y=wins_data.pop('tumor_class')
X=wins_data

#split the data into train/test - using 60:40
#import the module from sklearnmodelselection
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

#instantiate the model
my_model=DecisionTreeClassifier()

#train the model to fit
my_model.fit(X_train, y_train)

#predict using the model
y_pred=my_model.predict(X_test)
print(y_pred)
# Out:
# (699, 11)
# [2. 2. 2. 2. 2. 2. 4. 2. 2. 2. 4. 4. 2. 4. 4. 4. 2. 2. 2. 2. 2. 2. 4. 2.
#  4. 2. 4. 4. 2. 2. 2. 4. 4. 4. 4. 4. 2. 4. 2. 2. 2. 2. 2. 2. 2. 4. 2. 2.
#  2. 2. 2. 2. 4. 2. 4. 2. 4. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 4. 2. 2. 2. 2.
#  2. 2. 4. 4. 2. 2. 2. 2. 4. 2. 2. 4. 2. 2. 2. 4. 4. 2. 4. 4. 2. 2. 2. 4.
#  2. 2. 2. 2. 2. 4. 4. 2. 2. 4. 4. 2. 4. 2. 4. 2. 2. 2. 2. 2. 2. 2. 2. 2.
#  2. 4. 4. 4. 2. 4. 2. 4. 2. 2. 2. 4. 4. 2. 4. 2. 2. 2. 4. 4. 2. 2. 2. 4.
#  2. 4. 2. 4. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 4. 2. 2. 4. 4. 2. 2.
#  2. 2. 2. 4. 4. 2. 2. 2. 4. 4. 4. 4. 4. 2. 2. 2. 2. 4. 2. 2. 4. 2. 2. 2.
#  2. 4. 2. 4. 4. 4. 4. 2. 2. 2. 2. 2. 4. 4. 4. 2. 2. 2. 4. 2. 4. 2. 4. 2.
#  2. 2. 2. 2. 4. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 4. 2. 2. 2. 2. 2. 4. 2. 4.
#  2. 4. 4. 2. 2. 4. 4. 2. 2. 2. 2. 2. 2. 2. 4. 4. 2. 2. 4. 4. 2. 4. 2. 2.
#  2. 2. 4. 2. 4. 2. 2. 4. 2. 2. 4. 2. 2. 2. 4. 2.]

# %%
import numpy as np
import pandas as pd
from pandas import read_csv
from sklearn.impute import SimpleImputer
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier


#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#convert nuclei variable to numeric and force non numeric to NAN
wins_data['nuclei']=pd.to_numeric(wins_data['nuclei'], errors='coerce')

#check missing values
win_empty_data = wins_data[wins_data.isna().any(axis=1)]
# print('\nThese are the missing data sets:\n', win_empty_data)

#because ? cannot be converted to int, we convert all data to float
wins_data[wisconsin_headers] = wins_data[wisconsin_headers].applymap(float)

#sample code number is just an index
#not useful for learning so we will drop it
wins_data.drop('sample_code', axis=1, inplace=True)

#declaring new headers
new_wisconsin_headers = ['c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#use simpleimputer to replace missing values
imputer = SimpleImputer(strategy='mean')
imputer.fit(wins_data)
new_data = imputer.transform(wins_data)
wins_data = pd.DataFrame(new_data, columns = new_wisconsin_headers)

#seperate data into x train and y test groups - y variable is tumor_class, rest is x
y=wins_data.pop('tumor_class')
X=wins_data

#split the data into train/test - using 60:40
#import the module from sklearnmodelselection
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

#instantiate the model
my_model=DecisionTreeClassifier()

#train the model to fit
my_model.fit(X_train, y_train)

#predict using the model - one input - edit to get different results
pred_one=my_model.predict(X=[[5.0, 5.0, 5.0, 5.0, 5.0, 10.0, 3.0, 2.0, 1.0]])
print(pred_one)
# Out:
# (699, 11)
# [4.]

# %%
import numpy as np
import pandas as pd
from pandas import read_csv
from sklearn.impute import SimpleImputer
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


#declaring header names
wisconsin_headers = ['sample_code', 'c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#read the data using read_csv class of pandas
wins_data = read_csv(r'C:\Users\Lawre\Documents\MSc Applied AI\AE1 - AI and Business - Mental Health\winsconsin_b_cancer.csv', names=wisconsin_headers)

print(wins_data.shape)#print the dimension

#convert nuclei variable to numeric and force non numeric to NAN
wins_data['nuclei']=pd.to_numeric(wins_data['nuclei'], errors='coerce')

#check missing values
win_empty_data = wins_data[wins_data.isna().any(axis=1)]
# print('\nThese are the missing data sets:\n', win_empty_data)

#because ? cannot be converted to int, we convert all data to float
wins_data[wisconsin_headers] = wins_data[wisconsin_headers].applymap(float)

#sample code number is just an index
#not useful for learning so we will drop it
wins_data.drop('sample_code', axis=1, inplace=True)

#declaring new headers
new_wisconsin_headers = ['c_thickness', 'uni_cell_size', 'uni_cell_shape', 'marg_adhesion', 'epi_cell_size', 'nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'tumor_class']

#use simpleimputer to replace missing values
imputer = SimpleImputer(strategy='mean')
imputer.fit(wins_data)
new_data = imputer.transform(wins_data)
wins_data = pd.DataFrame(new_data, columns = new_wisconsin_headers)

#seperate data into x train and y test groups - y variable is tumor_class, rest is x
y=wins_data.pop('tumor_class')
X=wins_data

#split the data into train/test - using 60:40
#import the module from sklearnmodelselection
#using stratify parameter set to y so train and test data have same proportion of class label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1, stratify=y)

#instantiate the model
#try to tune the model more using - random, max depth, min samples, criterion
my_model=DecisionTreeClassifier(max_depth=4, min_samples_split=2, criterion='gini', random_state=1)

#train the model to fit
my_model.fit(X_train, y_train)

#predict using the model
# y_pred=my_model.predict(X_test)
pred_one=my_model.predict(X=[[6.0, 10.0, 10.0, 2.0, 8.0, 10.0, 7.0, 3.0, 3.0]])
print(pred_one)

# #compute test set accuracy
# model_accuracy=accuracy_score(y_test, y_pred)
# print('Model accuracy on Test Data: {:.2f}'.format(model_accuracy), '\n')

# #construction a confusion matrix
# matrix_info=confusion_matrix(y_test, y_pred)

# #print the confusion matrix
# print('The Confusion Matrix: \n', matrix_info, '\n')

# #construct the classification report
# class_report=classification_report(y_test, y_pred)
# print('Report of Classification: \n', class_report)
# Out:
# (699, 11)
# [4.]
